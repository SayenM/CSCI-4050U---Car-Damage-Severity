# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "data3a/training",
    labels="inferred",         
    label_mode="int",          
    batch_size=32,
    image_size=(256, 256),      
    shuffle=True,
)
# Out:
# Found 1383 files belonging to 3 classes.
# 2025-12-07 21:14:32.060964: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-12-07 21:14:32.061016: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-12-07 21:14:32.061028: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-12-07 21:14:32.061077: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-07 21:14:32.061120: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# 0.16s - Expected: /opt/anaconda3/envs/car-damage/lib/python3.11/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/attach.dylib to exist.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
    "data3a/validation",
    labels="inferred",
    label_mode="int",
    batch_size=32,
    image_size=(256, 256),
    shuffle=False,
)
# Out:
# Found 248 files belonging to 3 classes.

# %%
print(f"Length of the Train Batch: {len(train_ds)}")
print(f"Length of the Validation Batch: {len(val_ds)}")
# Out:
# Length of the Train Batch: 44
# Length of the Validation Batch: 8

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['01-minor', '02-moderate', '03-severe']

# %%
images, labels = next(iter(train_ds))

plt.figure(figsize=(12, 12))

for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    title = class_names[labels[i].numpy()]
    plt.title(f"Label: {title[3:]}")
    plt.axis("off")

plt.tight_layout()
plt.show()
